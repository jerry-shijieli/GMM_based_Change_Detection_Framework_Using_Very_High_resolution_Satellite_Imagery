# %%
import os
imgfile1 = os.path.join('dataset', 'k02-05m.tif')
imgfile2 = os.path.join('dataset', 'k12-05m.tif')

# %%
from skimage import io
img1 = io.imread(imgfile1)
type(img1)
# Out:
# numpy.ndarray

# %%
print img1.shape
# Out:
# (6894, 6972, 3)

# %%
img2 = io.imread(imgfile2)
print img2.shape
# Out:
# (6894, 6972, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(figsize=(16,35))
plt.subplot(121).imshow(img1)
plt.subplot(122).imshow(img2)
